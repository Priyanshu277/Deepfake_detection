# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000220.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000090.jpg
# /kaggle/input/dataset1/frames/akvmwkdyuv.mp4_000170.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000100.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000300.jpg
# /kaggle/input/dataset1/frames/ayqvfdhslr.mp4_000040.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bhaaboftbc.mp4_000160.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000270.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000040.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000280.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000030.jpg
# /kaggle/input/dataset1/frames/agrmhtjdlk.mp4_000070.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000110.jpg
# /kaggle/input/dataset1/frames/andaxzscny.mp4_000070.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000110.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000230.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000160.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000030.jpg
# /kaggle/input/dataset1/frames/ahfazfbntc.mp4_000260.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000220.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000120.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000240.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000130.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000120.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000280.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000100.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000140.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000220.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000040.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000290.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000130.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000050.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000210.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000120.jpg
# /kaggle/input/dataset1/frames/awhmfnnjih.mp4_000060.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000290.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000230.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000050.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000120.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000170.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000260.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000150.jpg
# /kaggle/input/dataset1/frames/ahfazfbntc.mp4_000150.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000130.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000300.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000020.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000290.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000240.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000220.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bgaogsjehq.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000210.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000300.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000080.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000300.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000070.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000070.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000170.jpg
# /kaggle/input/dataset1/frames/aevrfsexku.mp4_000010.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000190.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000040.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000270.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000050.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000070.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bgaogsjehq.mp4_000080.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000190.jpg
# /kaggle/input/dataset1/frames/avvdgsennp.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000020.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000120.jpg
# /kaggle/input/dataset1/frames/aytzyidmgs.mp4_000220.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000110.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000060.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000120.jpg
# /kaggle/input/dataset1/frames/asdpeebotb.mp4_000150.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000210.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000100.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000100.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000300.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000280.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000270.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000180.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000140.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000150.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000110.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000140.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000020.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000200.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000100.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000270.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000010.jpg
# /kaggle/input/dataset1/frames/akvmwkdyuv.mp4_000270.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000010.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000120.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000240.jpg
# /kaggle/input/dataset1/frames/awhmfnnjih.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000260.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bhpwpydzpo.mp4_000080.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000230.jpg
# /kaggle/input/dataset1/frames/adhsbajydo.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000080.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000070.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000010.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000250.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000080.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000190.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000160.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bejhvclboh.mp4_000240.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bjkmjilrxp.mp4_000270.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000260.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000290.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000150.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000170.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000200.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000150.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000060.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000040.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000270.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bgaogsjehq.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000250.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000110.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000080.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000260.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000260.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000130.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000230.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000300.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000210.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000140.jpg
# /kaggle/input/dataset1/frames/arrhsnjqku.mp4_000150.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000140.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000140.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000280.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000010.jpg
# /kaggle/input/dataset1/frames/apogckdfrz.mp4_000050.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000300.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000100.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000300.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000140.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000280.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000150.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000040.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000130.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000050.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bourlmzsio.mp4_000200.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000080.jpg
# /kaggle/input/dataset1/frames/abqwwspghj.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000040.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000170.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000230.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000280.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000200.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bchnbulevv.mp4_000020.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000270.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000170.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000110.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000060.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bofqajtwve.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000260.jpg
# /kaggle/input/dataset1/frames/adhsbajydo.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000030.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000240.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000160.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000260.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bhaaboftbc.mp4_000070.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000260.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000130.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000110.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000040.jpg
# /kaggle/input/dataset1/frames/aytzyidmgs.mp4_000280.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000060.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000120.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000050.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000180.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000230.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000180.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000290.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000200.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000180.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000170.jpg
# /kaggle/input/dataset1/frames/aneclqfpbt.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000150.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000040.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000190.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000240.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000230.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000280.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000160.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000180.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bjkmjilrxp.mp4_000260.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000060.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000230.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000220.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000170.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bofqajtwve.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000280.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000270.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000220.jpg
# /kaggle/input/dataset1/frames/ahfazfbntc.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000160.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000230.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000300.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000170.jpg
# /kaggle/input/dataset1/frames/avnqydkqjj.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bofqajtwve.mp4_000140.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000040.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bgaogsjehq.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000270.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000170.jpg
# /kaggle/input/dataset1/frames/arrhsnjqku.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000120.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000150.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000150.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000130.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000250.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000020.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000030.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000300.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000110.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000110.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000150.jpg
# /kaggle/input/dataset1/frames/agrmhtjdlk.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000270.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000160.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000110.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aytzyidmgs.mp4_000040.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000280.jpg
# /kaggle/input/dataset1/frames/aevrfsexku.mp4_000210.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000130.jpg
# /kaggle/input/dataset1/frames/agrmhtjdlk.mp4_000160.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000140.jpg
# /kaggle/input/dataset1/frames/agrmhtjdlk.mp4_000250.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000200.jpg
# /kaggle/input/dataset1/frames/andaxzscny.mp4_000110.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000260.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000250.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000180.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000200.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000250.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000080.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000020.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000270.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000110.jpg
# /kaggle/input/dataset1/frames/axoygtekut.mp4_000130.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000290.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000150.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000170.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000040.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000220.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000200.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000120.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bkwxhglwct.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000160.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000010.jpg
# /kaggle/input/dataset1/frames/acqfdwsrhi.mp4_000220.jpg
# /kaggle/input/dataset1/frames/aytzyidmgs.mp4_000030.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000250.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000030.jpg
# /kaggle/input/dataset1/frames/abqwwspghj.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000040.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000060.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000260.jpg
# /kaggle/input/dataset1/frames/abqwwspghj.mp4_000010.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000090.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000260.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000230.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000170.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000120.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000020.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bbvgxeczei.mp4_000300.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000010.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000280.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000200.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000040.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000220.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000130.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000270.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000200.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000030.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000030.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000090.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000150.jpg
# /kaggle/input/dataset1/frames/ayqvfdhslr.mp4_000130.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000190.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000180.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000060.jpg
# /kaggle/input/dataset1/frames/acqfdwsrhi.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000100.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000150.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000140.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000170.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000120.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000070.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000220.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000040.jpg
# /kaggle/input/dataset1/frames/blpchvmhxx.mp4_000090.jpg
# /kaggle/input/dataset1/frames/ayqvfdhslr.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bhaaboftbc.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000200.jpg
# /kaggle/input/dataset1/frames/acxwigylke.mp4_000050.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000070.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000040.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000160.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000260.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000230.jpg
# /kaggle/input/dataset1/frames/ayqvfdhslr.mp4_000230.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bgaogsjehq.mp4_000060.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bourlmzsio.mp4_000160.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000010.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000220.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000120.jpg
# /kaggle/input/dataset1/frames/andaxzscny.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000230.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000090.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000240.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000140.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000280.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000210.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bbvgxeczei.mp4_000240.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000190.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000090.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000020.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000050.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bejhvclboh.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bgaogsjehq.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000010.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000250.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000290.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000120.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aneclqfpbt.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bhpwpydzpo.mp4_000230.jpg
# /kaggle/input/dataset1/frames/apogckdfrz.mp4_000070.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000230.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000280.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000070.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000070.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000280.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000190.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000040.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000080.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000130.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bejhvclboh.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000040.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000140.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000250.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000140.jpg
# /kaggle/input/dataset1/frames/axoygtekut.mp4_000270.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000220.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000070.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000150.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000120.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000130.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000200.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000170.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000220.jpg
# /kaggle/input/dataset1/frames/blpchvmhxx.mp4_000170.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000200.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000270.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000110.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000200.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000010.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000080.jpg
# /kaggle/input/dataset1/frames/agrmhtjdlk.mp4_000220.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000230.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000120.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000020.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000010.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000190.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000040.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000010.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000030.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000010.jpg
# /kaggle/input/dataset1/frames/avvdgsennp.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000010.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000220.jpg
# /kaggle/input/dataset1/frames/bchnbulevv.mp4_000170.jpg
# /kaggle/input/dataset1/frames/acxwigylke.mp4_000250.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bkwxhglwct.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000300.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000260.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000110.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000170.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000080.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000200.jpg
# /kaggle/input/dataset1/frames/apogckdfrz.mp4_000010.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000190.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000020.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000130.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000140.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bhpwpydzpo.mp4_000050.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000040.jpg
# /kaggle/input/dataset1/frames/awhmfnnjih.mp4_000290.jpg
# /kaggle/input/dataset1/frames/aevrfsexku.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000060.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000140.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000090.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000090.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000110.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bjkmjilrxp.mp4_000050.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000220.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000020.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000080.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000200.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000230.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000210.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000280.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000250.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000300.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000160.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000300.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000270.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000100.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000240.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000260.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bchnbulevv.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bhaaboftbc.mp4_000090.jpg
# /kaggle/input/dataset1/frames/adhsbajydo.mp4_000210.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000020.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000200.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000150.jpg
# /kaggle/input/dataset1/frames/asdpeebotb.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000240.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000090.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000260.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000270.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000210.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000220.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bejhvclboh.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000070.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000230.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000020.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bofqajtwve.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bourlmzsio.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000260.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000140.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000090.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000020.jpg
# /kaggle/input/dataset1/frames/avvdgsennp.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000050.jpg
# /kaggle/input/dataset1/frames/asdpeebotb.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000230.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000290.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bchnbulevv.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000060.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000010.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000270.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000300.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000100.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000200.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000210.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000060.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000040.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000110.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000020.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bhaaboftbc.mp4_000170.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000140.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000240.jpg
# /kaggle/input/dataset1/frames/adhsbajydo.mp4_000260.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000220.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000200.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000170.jpg
# /kaggle/input/dataset1/frames/asdpeebotb.mp4_000200.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000070.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000150.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000110.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000020.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000290.jpg
# /kaggle/input/dataset1/frames/asdpeebotb.mp4_000180.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000180.jpg
# /kaggle/input/dataset1/frames/acxnxvbsxk.mp4_000050.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000030.jpg
# /kaggle/input/dataset1/frames/blpchvmhxx.mp4_000120.jpg
# /kaggle/input/dataset1/frames/apogckdfrz.mp4_000160.jpg
# /kaggle/input/dataset1/frames/blpchvmhxx.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000060.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000030.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000200.jpg
# /kaggle/input/dataset1/frames/blpchvmhxx.mp4_000290.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000270.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000190.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000050.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000030.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000250.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aneclqfpbt.mp4_000170.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000250.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000300.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000300.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000250.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000180.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000250.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000240.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000290.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000020.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000110.jpg
# /kaggle/input/dataset1/frames/axoygtekut.mp4_000280.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000110.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000260.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000030.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000010.jpg
# /kaggle/input/dataset1/frames/axoygtekut.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bdgipnyobr.mp4_000060.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000220.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000270.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000150.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000160.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000090.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000060.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000240.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000070.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000290.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000100.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000230.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000080.jpg
# /kaggle/input/dataset1/frames/avnqydkqjj.mp4_000230.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000020.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000030.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000240.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000060.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000140.jpg
# /kaggle/input/dataset1/frames/abqwwspghj.mp4_000300.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000180.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000120.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000050.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000270.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000240.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000180.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000080.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000180.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000150.jpg
# /kaggle/input/dataset1/frames/avvdgsennp.mp4_000250.jpg
# /kaggle/input/dataset1/frames/avnqydkqjj.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000250.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000030.jpg
# /kaggle/input/dataset1/frames/apgjqzkoma.mp4_000290.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000200.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000260.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000270.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000290.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000100.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000200.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000280.jpg
# /kaggle/input/dataset1/frames/avnqydkqjj.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000100.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000080.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000210.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000010.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000180.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000290.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000140.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000210.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000100.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000230.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000080.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000050.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000200.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000100.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000050.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000250.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000150.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000250.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000030.jpg
# /kaggle/input/dataset1/frames/acxwigylke.mp4_000180.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000230.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000020.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000210.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000230.jpg
# /kaggle/input/dataset1/frames/ahfazfbntc.mp4_000270.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000180.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000170.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000140.jpg
# /kaggle/input/dataset1/frames/acxwigylke.mp4_000200.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000220.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000300.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000220.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000150.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000160.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000050.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000140.jpg
# /kaggle/input/dataset1/frames/aneclqfpbt.mp4_000040.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aevrfsexku.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000040.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000220.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000090.jpg
# /kaggle/input/dataset1/frames/arrhsnjqku.mp4_000060.jpg
# /kaggle/input/dataset1/frames/adhsbajydo.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000050.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000290.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000040.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000240.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000170.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000220.jpg
# /kaggle/input/dataset1/frames/axwgcsyphv.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000250.jpg
# /kaggle/input/dataset1/frames/arkroixhey.mp4_000010.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bchnbulevv.mp4_000120.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000260.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000030.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bjkmjilrxp.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000110.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000260.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000200.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000120.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000030.jpg
# /kaggle/input/dataset1/frames/avnqydkqjj.mp4_000100.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000050.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000030.jpg
# ...
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000130.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000010.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000130.jpg
# /kaggle/input/dataset1/frames/atxvxouljq.mp4_000080.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000080.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000130.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000120.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000010.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000170.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000090.jpg
# /kaggle/input/dataset1/frames/acxwigylke.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000230.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000270.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000100.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000280.jpg
# /kaggle/input/dataset1/frames/augtsuxpzc.mp4_000090.jpg
# /kaggle/input/dataset1/frames/avnqydkqjj.mp4_000250.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000160.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000270.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000100.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000060.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000210.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000020.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000150.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000070.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bghphrsfxf.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000040.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000150.jpg
# /kaggle/input/dataset1/frames/ayqvfdhslr.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000240.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000010.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000110.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000290.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000040.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000080.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000300.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000270.jpg
# /kaggle/input/dataset1/frames/avvdgsennp.mp4_000120.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000270.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bjjbwsqjir.mp4_000060.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000060.jpg
# /kaggle/input/dataset1/frames/asaxgevnnp.mp4_000280.jpg
# /kaggle/input/dataset1/frames/axoygtekut.mp4_000140.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000210.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000200.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000090.jpg
# /kaggle/input/dataset1/frames/andaxzscny.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000030.jpg
# /kaggle/input/dataset1/frames/acqfdwsrhi.mp4_000090.jpg
# /kaggle/input/dataset1/frames/alninxcyhg.mp4_000160.jpg
# /kaggle/input/dataset1/frames/blzydqdfem.mp4_000180.jpg
# /kaggle/input/dataset1/frames/aczrgyricp.mp4_000260.jpg
# /kaggle/input/dataset1/frames/benmsfzfaz.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000230.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000190.jpg
# /kaggle/input/dataset1/frames/atkdltyyen.mp4_000250.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aknbdpmgua.mp4_000070.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000090.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000150.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000270.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000090.jpg
# /kaggle/input/dataset1/frames/aknmpoonls.mp4_000290.jpg
# /kaggle/input/dataset1/frames/ahbweevwpv.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000160.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000270.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bmehkyanbj.mp4_000300.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000030.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000150.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000130.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bbhtdfuqxq.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bgmlwsoamc.mp4_000240.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000220.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000140.jpg
# /kaggle/input/dataset1/frames/aelzhcnwgf.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000300.jpg
# /kaggle/input/dataset1/frames/acqfdwsrhi.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000230.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000140.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000040.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000240.jpg
# /kaggle/input/dataset1/frames/avgiuextiz.mp4_000080.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000160.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000280.jpg
# /kaggle/input/dataset1/frames/beyebyhrph.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000260.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bnbuonyoje.mp4_000150.jpg
# /kaggle/input/dataset1/frames/anpuvshzoo.mp4_000040.jpg
# /kaggle/input/dataset1/frames/aelfnikyqj.mp4_000050.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000170.jpg
# /kaggle/input/dataset1/frames/axntxmycwd.mp4_000110.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000260.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000220.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bggsurpgpr.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000260.jpg
# /kaggle/input/dataset1/frames/aqpnvjhuzw.mp4_000230.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000190.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000040.jpg
# /kaggle/input/dataset1/frames/ahqqqilsxt.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bofqajtwve.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bbvgxeczei.mp4_000200.jpg
# /kaggle/input/dataset1/frames/awhmfnnjih.mp4_000040.jpg
# /kaggle/input/dataset1/frames/awnwkrqibf.mp4_000220.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000040.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bffwsjxghk.mp4_000110.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000290.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000210.jpg
# /kaggle/input/dataset1/frames/atzdznmder.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000110.jpg
# /kaggle/input/dataset1/frames/afoovlsmtx.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bhsluedavd.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bgvhtpzknn.mp4_000280.jpg
# /kaggle/input/dataset1/frames/aybumesmpk.mp4_000260.jpg
# /kaggle/input/dataset1/frames/altziddtxi.mp4_000090.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000170.jpg
# /kaggle/input/dataset1/frames/awukslzjra.mp4_000250.jpg
# /kaggle/input/dataset1/frames/apatcsqejh.mp4_000210.jpg
# /kaggle/input/dataset1/frames/atyntldecu.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000200.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000010.jpg
# /kaggle/input/dataset1/frames/aneclqfpbt.mp4_000070.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000080.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bhaaboftbc.mp4_000230.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000080.jpg
# /kaggle/input/dataset1/frames/avssvvsdhz.mp4_000190.jpg
# /kaggle/input/dataset1/frames/amaivqofda.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000020.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000220.jpg
# /kaggle/input/dataset1/frames/axczxisdtb.mp4_000150.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bbvgxeczei.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bbvgxeczei.mp4_000070.jpg
# /kaggle/input/dataset1/frames/bmhvktyiwp.mp4_000260.jpg
# /kaggle/input/dataset1/frames/apogckdfrz.mp4_000250.jpg
# /kaggle/input/dataset1/frames/agqphdxmwt.mp4_000160.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000050.jpg
# /kaggle/input/dataset1/frames/ajqslcypsw.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aorjvbyxhw.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000030.jpg
# /kaggle/input/dataset1/frames/abofeumbvv.mp4_000030.jpg
# /kaggle/input/dataset1/frames/agrmhtjdlk.mp4_000040.jpg
# /kaggle/input/dataset1/frames/apogckdfrz.mp4_000150.jpg
# /kaggle/input/dataset1/frames/avibnnhwhp.mp4_000160.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000250.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000070.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000230.jpg
# /kaggle/input/dataset1/frames/bntlodcfeg.mp4_000190.jpg
# /kaggle/input/dataset1/frames/akzbnazxtz.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000110.jpg
# /kaggle/input/dataset1/frames/axwovszumc.mp4_000030.jpg
# /kaggle/input/dataset1/frames/bilnggbxgu.mp4_000060.jpg
# /kaggle/input/dataset1/frames/atvmxvwyns.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000300.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000230.jpg
# /kaggle/input/dataset1/frames/aettqgevhz.mp4_000130.jpg
# /kaggle/input/dataset1/frames/acifjvzvpm.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bchnbulevv.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bndybcqhfr.mp4_000130.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000180.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bopqhhalml.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bahdpoesir.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bkvetcojbt.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aytzyidmgs.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bmjmjmbglm.mp4_000200.jpg
# /kaggle/input/dataset1/frames/aevrfsexku.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aufmsmnoye.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bhbdugnurr.mp4_000160.jpg
# /kaggle/input/dataset1/frames/bejhvclboh.mp4_000120.jpg
# /kaggle/input/dataset1/frames/azpuxunqyo.mp4_000160.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000170.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000170.jpg
# /kaggle/input/dataset1/frames/bdxuhamuqx.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bourlmzsio.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bmbbkwmxqj.mp4_000200.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bddjdhzfze.mp4_000190.jpg
# /kaggle/input/dataset1/frames/aklqzsddfl.mp4_000270.jpg
# /kaggle/input/dataset1/frames/ayqvfdhslr.mp4_000190.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000140.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000090.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000120.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000090.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000050.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000300.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000180.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000100.jpg
# /kaggle/input/dataset1/frames/bgwmmujlmc.mp4_000060.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000230.jpg
# /kaggle/input/dataset1/frames/adhsbajydo.mp4_000110.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000190.jpg
# /kaggle/input/dataset1/frames/asmpfjfzif.mp4_000250.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000080.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000190.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000100.jpg
# /kaggle/input/dataset1/frames/arlmiizoob.mp4_000220.jpg
# /kaggle/input/dataset1/frames/aagfhgtpmv.mp4_000040.jpg
# /kaggle/input/dataset1/frames/adylbeequz.mp4_000060.jpg
# /kaggle/input/dataset1/frames/alvgwypubw.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000040.jpg
# /kaggle/input/dataset1/frames/asvcrfdpnq.mp4_000200.jpg
# /kaggle/input/dataset1/frames/akxoopqjqz.mp4_000200.jpg
# /kaggle/input/dataset1/frames/amowujxmzc.mp4_000300.jpg
# /kaggle/input/dataset1/frames/avfitoutyn.mp4_000020.jpg
# /kaggle/input/dataset1/frames/bbvgxeczei.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bnjcdrfuov.mp4_000280.jpg
# /kaggle/input/dataset1/frames/avmjormvsx.mp4_000100.jpg
# /kaggle/input/dataset1/frames/aslsvlvpth.mp4_000150.jpg
# /kaggle/input/dataset1/frames/avvdgsennp.mp4_000040.jpg
# /kaggle/input/dataset1/frames/ajwpjhrbcv.mp4_000230.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000130.jpg
# /kaggle/input/dataset1/frames/beboztfcme.mp4_000040.jpg
# /kaggle/input/dataset1/frames/alaijyygdv.mp4_000100.jpg
# /kaggle/input/dataset1/frames/agdkmztvby.mp4_000040.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000150.jpg
# /kaggle/input/dataset1/frames/ahfazfbntc.mp4_000130.jpg
# /kaggle/input/dataset1/frames/abarnvbtwb.mp4_000300.jpg
# /kaggle/input/dataset1/frames/adohikbdaz.mp4_000270.jpg
# /kaggle/input/dataset1/frames/boovltmuwi.mp4_000250.jpg
# /kaggle/input/dataset1/frames/aladcziidp.mp4_000110.jpg
# /kaggle/input/dataset1/frames/andaxzscny.mp4_000210.jpg
# /kaggle/input/dataset1/frames/bmjzrlszhi.mp4_000230.jpg
# /kaggle/input/dataset1/frames/ahdbuwqxit.mp4_000300.jpg
# /kaggle/input/dataset1/frames/bdbhekrrwo.mp4_000090.jpg
# /kaggle/input/dataset1/frames/avtycwsgyb.mp4_000300.jpg
# /kaggle/input/dataset1/frames/aybgughjxh.mp4_000050.jpg
# /kaggle/input/dataset1/frames/bguwlyazau.mp4_000030.jpg
# /kaggle/input/dataset1/frames/aipfdnwpoo.mp4_000090.jpg
# /kaggle/input/dataset1/frames/avywawptfc.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000280.jpg
# /kaggle/input/dataset1/frames/aapnvogymq.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bofqajtwve.mp4_000010.jpg
# /kaggle/input/dataset1/frames/bctvsmddgq.mp4_000280.jpg
# /kaggle/input/dataset1/frames/bdnaqemxmr.mp4_000270.jpg
# /kaggle/input/dataset1/frames/bjsmaqefoi.mp4_000130.jpg
# /kaggle/input/dataset1/frames/bbhpvrmbse.mp4_000170.jpg
# /kaggle/input/dataset1/frames/azsmewqghg.mp4_000110.jpg
# /kaggle/input/dataset1/frames/bmioepcpsx.mp4_000240.jpg
# /kaggle/input/dataset1/frames/bkmdzhfzfh.mp4_000170.jpg

# %%
import json
import os
from glob import glob
import cv2
import numpy as np
import pandas as pd
from keras.preprocessing.image import img_to_array

# Load metadata
with open('/kaggle/input/dataset1/frames/metadata.json') as f:
    metadata = json.load(f)

# Create a DataFrame to map frames with their labels
data = []
frames_dir = '/kaggle/input/dataset1/frames'
for video_id, info in metadata.items():
    label = 1 if info['label'] == 'FAKE' else 0
    # Loop through each frame for that video
    frame_paths = glob(os.path.join(frames_dir, f"{video_id}_*.jpg"))
    for frame in frame_paths:
        data.append([frame, label])

df = pd.DataFrame(data, columns=['frame_path', 'label'])

# %%
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import load_img

IMG_SIZE = (299, 299)

def preprocess_frame(frame_path):
    img = load_img(frame_path, target_size=IMG_SIZE)
    img = img_to_array(img)
    img = preprocess_input(img)
    return img

# %%
from sklearn.model_selection import train_test_split
from keras.applications.xception import Xception
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.optimizers import Adam

# Convert the list of frame paths to a numpy array of images
frames = np.array([preprocess_frame(frame_path) for frame_path in df['frame_path']])
labels = np.array(df['label'])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(frames, labels, test_size=0.2, random_state=42)

# Build and compile the model
base_model = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=16)
# Out:
# Epoch 1/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 42s 174ms/step - accuracy: 0.8529 - loss: 0.3920 - val_accuracy: 0.8806 - val_loss: 0.2600
# Epoch 2/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - accuracy: 0.8981 - loss: 0.2346 - val_accuracy: 0.8952 - val_loss: 0.2231
# Epoch 3/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - accuracy: 0.9258 - loss: 0.1730 - val_accuracy: 0.9135 - val_loss: 0.1836
# Epoch 4/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9285 - loss: 0.1569 - val_accuracy: 0.9330 - val_loss: 0.1563
# Epoch 5/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 29s 141ms/step - accuracy: 0.9333 - loss: 0.1411 - val_accuracy: 0.9403 - val_loss: 0.1477

# %%
# Get predictions for the test set
y_pred_probs = model.predict(X_test)

# Convert probabilities to binary classification (0 or 1)
y_pred = (y_pred_probs > 0.5).astype("int32")
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step

# %%
import pandas as pd

# Create a DataFrame with true labels and predictions
results_df = pd.DataFrame({'True Label': y_test, 'Predicted Label': y_pred.flatten()})

# Save to a CSV file
results_df.to_csv('predictions.csv', index=False)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Classification report (Precision, Recall, F1-score)
report = classification_report(y_test, y_pred, target_names=['Real', 'Fake'])
print(report)

# Save classification report to a file
with open('classification_report.txt', 'w') as f:
    f.write(f"Accuracy: {accuracy}\n")
    f.write(report)
# Out:
# Accuracy: 0.9403166869671132
#               precision    recall  f1-score   support
#
#         Real       0.87      0.81      0.84       157
#         Fake       0.96      0.97      0.96       664
#
#     accuracy                           0.94       821
#    macro avg       0.91      0.89      0.90       821
# weighted avg       0.94      0.94      0.94       821

# %%
# Save the model architecture and weights
model.save('deepfake_detection_model.h5')

# %%
import tensorflow as tf

# Check TensorFlow version
print("TensorFlow version:", tf.__version__)

# Check Keras version (usually part of TensorFlow)
print("Keras version:", tf.keras.__version__)
# Out:
# TensorFlow version: 2.16.1
# Keras version: 3.3.3

# %%
import json
import os
from glob import glob
import cv2
import numpy as np
import pandas as pd
from keras.preprocessing.image import img_to_array
from sklearn.utils import class_weight
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.optimizers import Adam

# Load metadata
with open('/kaggle/input/dataset1/frames/metadata.json') as f:
    metadata = json.load(f)

# Create a DataFrame to map frames with their labels
data = []
frames_dir = '/kaggle/input/dataset1/frames'
for video_id, info in metadata.items():
    label = 1 if info['label'] == 'FAKE' else 0
    # Loop through each frame for that video
    frame_paths = glob(os.path.join(frames_dir, f"{video_id}_*.jpg"))
    for frame in frame_paths:
        data.append([frame, label])

df = pd.DataFrame(data, columns=['frame_path', 'label'])

IMG_SIZE = (299, 299)

def preprocess_frame(frame_path):
    img = load_img(frame_path, target_size=IMG_SIZE)
    img = img_to_array(img)
    img = preprocess_input(img)
    return img

# Convert the list of frame paths to a numpy array of images
frames = np.array([preprocess_frame(frame_path) for frame_path in df['frame_path']])
labels = np.array(df['label'])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(frames, labels, test_size=0.2, random_state=42)

# Compute class weights
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))

# Build and compile the model
base_model = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with class weights
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=16, class_weight=class_weights_dict)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

# Predict on test set
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

# Print confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, y_pred_classes))
print(classification_report(y_test, y_pred_classes))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725755278.312447     103 service.cc:145] XLA service 0x7e8a2013bb70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725755278.312500     103 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1725755278.312504     103 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   2/206 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - accuracy: 0.7656 - loss: 0.6537
# I0000 00:00:1725755289.236427     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 53s 183ms/step - accuracy: 0.7020 - loss: 0.6000 - val_accuracy: 0.8295 - val_loss: 0.3321
# Epoch 2/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 26s 127ms/step - accuracy: 0.8384 - loss: 0.3400 - val_accuracy: 0.8916 - val_loss: 0.2737
# Epoch 3/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 27s 132ms/step - accuracy: 0.8767 - loss: 0.2645 - val_accuracy: 0.7966 - val_loss: 0.4236
# Epoch 4/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.8850 - loss: 0.2241 - val_accuracy: 0.7771 - val_loss: 0.5017
# Epoch 5/5
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9067 - loss: 0.1819 - val_accuracy: 0.8819 - val_loss: 0.2615
# 2024-09-08 00:30:45.630052: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=2} for conv (f32[32,128,147,147]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,147,147]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-09-08 00:30:45.634981: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.005060639s
# Trying algorithm eng3{k11=2} for conv (f32[32,128,147,147]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,147,147]{3,2,1,0}, f32[128,1,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=128, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 40s 772ms/step - accuracy: 0.8921 - loss: 0.2405
# Test Accuracy: 0.88
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step
# [[148   9]
#  [ 88 576]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.94      0.75       157
#            1       0.98      0.87      0.92       664
#
#     accuracy                           0.88       821
#    macro avg       0.81      0.91      0.84       821
# weighted avg       0.92      0.88      0.89       821

# %%
# Save the model architecture and weights
model.save('deepfake.h5')
